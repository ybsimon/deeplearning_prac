# %%
from __future__ import division, print_function, unicode_literals

import tensorflow as tf

# Common imports
import numpy as np
import os
import sys
from functools import partial

n_inputs = 28 * 28
n_hidden1 = 300
n_hidden2 = 150  # codings
n_hidden3 = n_hidden1
n_outputs = n_inputs

learning_rate = 0.01
l2_reg = 0.0001

X = tf.placeholder(tf.float32, shape=[None, n_inputs])

he_init = tf.contrib.layers.variance_scaling_initializer() # He initialization
l2_regularizer = tf.contrib.layers.l2_regularizer(l2_reg)
my_dense_layer = partial(tf.layers.dense,
                         activation=tf.nn.elu,
                         kernel_initializer=he_init,
                         kernel_regularizer=l2_regularizer)

hidden1 = my_dense_layer(X, n_hidden1)
hidden2 = my_dense_layer(hidden1, n_hidden2)
hidden3 = my_dense_layer(hidden2, n_hidden3)
outputs = my_dense_layer(hidden3, n_outputs, activation=None)

reconstruction_loss = tf.reduce_mean(tf.square(outputs - X))

reg_losses = tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)
loss = tf.add_n([reconstruction_loss] + reg_losses)

optimizer = tf.train.AdamOptimizer(learning_rate)
training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/")
n_epochs = 5
batch_size = 150

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        n_batches = mnist.train.num_examples // batch_size
        for iteration in range(n_batches):
            print("\r{}%".format(100 * iteration // n_batches), end="") 
            sys.stdout.flush()                                         
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch})
        loss_train = reconstruction_loss.eval(feed_dict={X: X_batch})   
        print("\r{}".format(epoch), "Train MSE:", loss_train)           
        saver.save(sess, "./my_model_all_layers.ckpt")
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# 0 Train MSE: 0.020531
# 1 %Train MSE: 0.0120206
# 2 Train MSE: 0.0107345
# 39% Train MSE: 0.00967614
# 4 Train MSE: 0.0100528

# %%
# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

PROJECT_ROOT_DIR = "."
CHAPTER_ID = "autoencoders"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

def plot_image(image, shape=[28, 28]):
    plt.imshow(image.reshape(shape), cmap="Greys", interpolation="nearest")
    plt.axis("off")
    
def show_reconstructed_digits(X, outputs, model_path = None, n_test_digits = 2):
    with tf.Session() as sess:
        if model_path:
            saver.restore(sess, model_path)
        X_test = mnist.test.images[:n_test_digits]
        outputs_val = outputs.eval(feed_dict={X: X_test})

    fig = plt.figure(figsize=(8, 3 * n_test_digits))
    for digit_index in range(n_test_digits):
        plt.subplot(n_test_digits, 2, digit_index * 2 + 1)
        plot_image(X_test[digit_index])
        plt.subplot(n_test_digits, 2, digit_index * 2 + 2)
        plot_image(outputs_val[digit_index])

# %%
show_reconstructed_digits(X, outputs, "./my_model_all_layers.ckpt")
save_fig("reconstruction_plot")
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_all_layers.ckpt
# Saving figure reconstruction_plot

# %%
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# %%
reset_graph()

n_inputs = 28 * 28
n_hidden1 = 300
n_hidden2 = 150  # codings
n_hidden3 = n_hidden1
n_outputs = n_inputs

learning_rate = 0.01
l2_reg = 0.0005

# %%
activation = tf.nn.elu
regularizer = tf.contrib.layers.l2_regularizer(l2_reg)
initializer = tf.contrib.layers.variance_scaling_initializer()

X = tf.placeholder(tf.float32, shape=[None, n_inputs])

weights1_init = initializer([n_inputs, n_hidden1])
weights2_init = initializer([n_hidden1, n_hidden2])

weights1 = tf.Variable(weights1_init, dtype=tf.float32, name="weights1")
weights2 = tf.Variable(weights2_init, dtype=tf.float32, name="weights2")
weights3 = tf.transpose(weights2, name="weights3")  # tied weights
weights4 = tf.transpose(weights1, name="weights4")  # tied weights

biases1 = tf.Variable(tf.zeros(n_hidden1), name="biases1")
biases2 = tf.Variable(tf.zeros(n_hidden2), name="biases2")
biases3 = tf.Variable(tf.zeros(n_hidden3), name="biases3")
biases4 = tf.Variable(tf.zeros(n_outputs), name="biases4")

hidden1 = activation(tf.matmul(X, weights1) + biases1)
hidden2 = activation(tf.matmul(hidden1, weights2) + biases2)
hidden3 = activation(tf.matmul(hidden2, weights3) + biases3)
outputs = tf.matmul(hidden3, weights4) + biases4

reconstruction_loss = tf.reduce_mean(tf.square(outputs - X))
reg_loss = regularizer(weights1) + regularizer(weights2)
loss = reconstruction_loss + reg_loss

optimizer = tf.train.AdamOptimizer(learning_rate)
training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()

# %%
saver = tf.train.Saver()

# %%
n_epochs = 5
batch_size = 150

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        n_batches = mnist.train.num_examples // batch_size
        for iteration in range(n_batches):
            print("\r{}%".format(100 * iteration // n_batches), end="")
            sys.stdout.flush()
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch})
        loss_train = reconstruction_loss.eval(feed_dict={X: X_batch})
        print("\r{}".format(epoch), "Train MSE:", loss_train)
        saver.save(sess, "./my_model_tying_weights.ckpt")
# Out:
# 0 Train MSE: 0.0159341
# 1 Train MSE: 0.0164315
# 2 Train MSE: 0.0167725
# 3 Train MSE: 0.0174328
# 4 Train MSE: 0.0177267

# %%
reset_graph()

n_inputs = 28 * 28
n_hidden1 = 300
n_hidden2 = 150  # codings
n_hidden3 = n_hidden1
n_outputs = n_inputs

learning_rate = 0.01
l2_reg = 0.0001

activation = tf.nn.elu
regularizer = tf.contrib.layers.l2_regularizer(l2_reg)
initializer = tf.contrib.layers.variance_scaling_initializer()

X = tf.placeholder(tf.float32, shape=[None, n_inputs])

weights1_init = initializer([n_inputs, n_hidden1])
weights2_init = initializer([n_hidden1, n_hidden2])
weights3_init = initializer([n_hidden2, n_hidden3])
weights4_init = initializer([n_hidden3, n_outputs])

weights1 = tf.Variable(weights1_init, dtype=tf.float32, name="weights1")
weights2 = tf.Variable(weights2_init, dtype=tf.float32, name="weights2")
weights3 = tf.Variable(weights3_init, dtype=tf.float32, name="weights3")
weights4 = tf.Variable(weights4_init, dtype=tf.float32, name="weights4")

biases1 = tf.Variable(tf.zeros(n_hidden1), name="biases1")
biases2 = tf.Variable(tf.zeros(n_hidden2), name="biases2")
biases3 = tf.Variable(tf.zeros(n_hidden3), name="biases3")
biases4 = tf.Variable(tf.zeros(n_outputs), name="biases4")

hidden1 = activation(tf.matmul(X, weights1) + biases1)
hidden2 = activation(tf.matmul(hidden1, weights2) + biases2)
hidden3 = activation(tf.matmul(hidden2, weights3) + biases3)
outputs = tf.matmul(hidden3, weights4) + biases4

reconstruction_loss = tf.reduce_mean(tf.square(outputs - X))

# %%
optimizer = tf.train.AdamOptimizer(learning_rate)

with tf.name_scope("phase1"):
    phase1_outputs = tf.matmul(hidden1, weights4) + biases4
    phase1_reconstruction_loss = tf.reduce_mean(tf.square(phase1_outputs - X))
    phase1_reg_loss = regularizer(weights1) + regularizer(weights4)
    phase1_loss = phase1_reconstruction_loss + phase1_reg_loss
    phase1_training_op = optimizer.minimize(phase1_loss)

with tf.name_scope("phase2"):
    phase2_reconstruction_loss = tf.reduce_mean(tf.square(hidden3 - hidden1))
    phase2_reg_loss = regularizer(weights2) + regularizer(weights3)
    phase2_loss = phase2_reconstruction_loss + phase2_reg_loss
    train_vars = [weights2, biases2, weights3, biases3]
    phase2_training_op = optimizer.minimize(phase2_loss, var_list=train_vars)

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
training_ops = [phase1_training_op, phase2_training_op]
reconstruction_losses = [phase1_reconstruction_loss, phase2_reconstruction_loss]
n_epochs = [4, 4]
batch_sizes = [150, 150]

with tf.Session() as sess:
    init.run()
    for phase in range(2):
        print("Training phase #{}".format(phase + 1))
        for epoch in range(n_epochs[phase]):
            n_batches = mnist.train.num_examples // batch_sizes[phase]
            for iteration in range(n_batches):
                print("\r{}%".format(100 * iteration // n_batches), end="")
                sys.stdout.flush()
                X_batch, y_batch = mnist.train.next_batch(batch_sizes[phase])
                sess.run(training_ops[phase], feed_dict={X: X_batch})
            loss_train = reconstruction_losses[phase].eval(feed_dict={X: X_batch})
            print("\r{}".format(epoch), "Train MSE:", loss_train)
            saver.save(sess, "./my_model_one_at_a_time.ckpt")
    loss_test = reconstruction_loss.eval(feed_dict={X: mnist.test.images})
    print("Test MSE:", loss_test)
# Out:
# Training phase #1
# 0 Train MSE: 0.00804847
# 1 Train MSE: 0.0074826
# 2 Train MSE: 0.00763566
# 3 Train MSE: 0.00776686
# Training phase #2
# 0 Train MSE: 0.220101
# 1 Train MSE: 0.0044097
# 2 Train MSE: 0.00240984
# 3 Train MSE: 0.00192531
# Test MSE: 0.00972138

# %%
training_ops = [phase1_training_op, phase2_training_op]
reconstruction_losses = [phase1_reconstruction_loss, phase2_reconstruction_loss]
n_epochs = [4, 4]
batch_sizes = [150, 150]

import numpy.random as rnd
rnd.permutation(1)


with tf.Session() as sess:
    init.run()
    
    for phase in range(2):
        print("Training phase #{}".format(phase + 1))
        if phase == 1:
            hidden1_cache = hidden1.eval(feed_dict={X: mnist.train.images})
        for epoch in range(n_epochs[phase]):
            n_batches = mnist.train.num_examples // batch_sizes[phase]
            for iteration in range(n_batches):
                print("\r{}%".format(100 * iteration // n_batches), end="")
                sys.stdout.flush()
                if phase == 1:
                    indices = rnd.permutation(mnist.train.num_examples)
                    hidden1_batch = hidden1_cache[indices[:batch_sizes[phase]]]
                    feed_dict = {hidden1: hidden1_batch}
                    sess.run(training_ops[phase], feed_dict=feed_dict)
                else:
                    X_batch, y_batch = mnist.train.next_batch(batch_sizes[phase])
                    feed_dict = {X: X_batch}
                    sess.run(training_ops[phase], feed_dict=feed_dict)
            loss_train = reconstruction_losses[phase].eval(feed_dict=feed_dict)
            print("\r{}".format(epoch), "Train MSE:", loss_train)
            saver.save(sess, "./my_model_cache_frozen.ckpt")
    loss_test = reconstruction_loss.eval(feed_dict={X: mnist.test.images})
    print("Test MSE:", loss_test)
    
    tvars = tf.trainable_variables()
    
    tvars_vals = sess.run(tvars)
    
    for var, val in zip(tvars, tvars_vals):
        print(var.name, val)
# Out:
# Training phase #1
# 0 Train MSE: 0.00774872
# 1 Train MSE: 0.00749705
# 2 Train MSE: 0.00765727
# 3 Train MSE: 0.00768713
# Training phase #2
# 0 Train MSE: 0.191614
# 1 Train MSE: 0.00513991
# 2 Train MSE: 0.00258615
# 3 Train MSE: 0.00206444
# Test MSE: 0.00980091
# weights1:0 [[ -3.01917848e-32   4.76019376e-33  -1.31524829e-32 ...,   7.93909294e-07
#    -4.53817756e-32  -7.23645137e-32]
#  [ -4.56205655e-32   4.50903294e-32  -8.51394454e-32 ...,   6.24020463e-32
#     3.98086217e-32  -2.08346144e-12]
#  [  6.66831849e-32  -3.04659924e-33  -8.69466152e-34 ...,   6.73385465e-33
#    -5.99417954e-32   5.58566704e-33]
#  ...,
#  [ -2.11109193e-31   5.37719546e-32  -1.46131580e-34 ...,   2.58409041e-32
#     2.26940322e-32  -1.27795067e-31]
#  [  2.06705157e-32   5.76183602e-32  -1.78907325e-30 ...,  -7.38883423e-32
#     7.72919274e-33   3.56996400e-32]
#  [  2.80455849e-32  -4.06360404e-32   1.39505812e-31 ...,  -2.28120477e-31
#    -1.03827607e-31  -3.55114727e-32]]
# weights2:0 [[ 0.01091096 -0.01067686  0.01005889 ...,  0.0044496   0.07224447
#    0.00105031]
#  [ 0.00104944  0.01221322  0.00390036 ...,  0.00559814 -0.03783936
#    0.02434285]
#  [ 0.00346968  0.00360585  0.00364874 ..., -0.00340061  0.01965092
#    0.02107614]
#  ...,
#  [-0.0224848   0.00526654  0.02910441 ...,  0.02962478  0.00026953
#    0.03206979]
#  [ 0.00360233  0.01989045 -0.01708863 ..., -0.04366088  0.05616972
#   -0.00279618]
#  [-0.01772136 -0.00738761  0.02455154 ...,  0.13310362  0.04837337
#   -0.04530842]]
# weights3:0 [[  7.09148590e-03  -3.72120575e-03  -9.81659442e-03 ...,  -2.68470235e-02
#    -1.56308264e-02  -4.63217199e-02]
#  [  3.95466387e-03   1.25511922e-02  -1.02236844e-03 ...,  -2.41277777e-02
#     1.67190079e-02  -2.94315480e-02]
#  [ -2.02097911e-02   5.49551612e-03  -1.62474886e-02 ...,   6.52524643e-03
#    -4.41649742e-02   2.67017353e-02]
#  ...,
#  [  3.53547628e-03  -1.78920734e-03  -2.89432728e-03 ...,   3.69283780e-02
#    -4.98339385e-02   1.31718263e-01]
#  [  5.89141101e-02  -4.93821576e-02   1.39615340e-02 ...,  -1.34424074e-02
#     5.13158664e-02   4.01464924e-02]
#  [ -1.31631859e-05   1.21364957e-02  -7.86874630e-03 ...,   1.77062526e-02
#    -2.61340290e-02  -7.59379044e-02]]
# weights4:0 [[  3.09417317e-07   1.15204909e-06   7.71577504e-08 ...,   2.00282848e-08
#    -1.18320294e-07   1.62322593e-07]
#  [ -1.26385009e-06  -3.82378266e-06  -3.24963935e-07 ...,  -7.32319663e-08
#     5.90440379e-07  -6.27678048e-07]
#  [  5.12216225e-08  -5.47666517e-08  -7.58622676e-09 ...,   9.98828575e-10
#    -4.28180229e-08   1.48772861e-08]
#  ...,
#  [ -6.65776724e-07  -2.32590719e-06  -1.35001230e-07 ...,  -2.52224321e-08
#     4.79271023e-07  -3.58217250e-07]
#  [  7.76043265e-08   3.63738792e-07  -5.86163473e-09 ...,  -6.06319617e-09
#    -2.56710475e-09   1.56627902e-08]
#  [ -2.96605151e-07  -1.07789242e-06  -5.74650194e-08 ...,  -1.18816432e-08
#     1.27595285e-07  -1.37786358e-07]]
# biases1:0 [-0.01164127 -0.02055359 -0.0161562   0.03157194  0.10241339  0.01067312
#   0.01262258 -0.03790516  0.07922143  0.01801217 -0.04701015  0.02152587
#  -0.00205937 -0.02961396 -0.06107808  0.04282207 -0.05962295 -0.00172622
#  -0.02625108  0.04209347 -0.01661155  0.0634155  -0.09241435 -0.00980704
#  -0.0181256   0.00078517  0.05202305 -0.01706955  0.00326644  0.01830448
#  -0.01620051 -0.04853618 -0.01793103  0.05350834 -0.00287057 -0.00045231
#  -0.06196706 -0.04629557 -0.10733205 -0.10090984 -0.00363725  0.05774737
#   0.00525693 -0.00250002 -0.02809054 -0.00413041 -0.04117588  0.00418956
#  -0.10291997 -0.009025    0.02538132 -0.03290777 -0.0103151  -0.01467208
#   0.04931419 -0.0259891  -0.02512175 -0.09427436 -0.09839915 -0.0632913
#  -0.00852754 -0.04363071 -0.04823193  0.01616759 -0.07034831 -0.07218502
#   0.02722398  0.34285739 -0.05124454  0.02290858 -0.04143276 -0.03763695
#  -0.01925539 -0.0673806  -0.01902956 -0.00147458  0.03311855 -0.02774393
#  -0.06881043 -0.04530167  0.05566829  0.05240361  0.09412814 -0.0259508
#  -0.10024329 -0.04533296 -0.0356623   0.0025684  -0.1125889  -0.13510408
#  -0.03020136 -0.07888947 -0.00586761  0.00405659 -0.09452777 -0.09225748
#  -0.02573225  0.02236841 -0.02806179 -0.04770403 -0.00838736 -0.07614842
#   0.04490385 -0.05712908 -0.04150598 -0.04921877  0.01501936 -0.00748818
#  -0.00286594 -0.02817468 -0.03370857 -0.02047971 -0.01052445 -0.02803914
#   0.01116272 -0.03053861 -0.03225225  0.15699175  0.01590765 -0.03493984
#  -0.0031122  -0.00664678 -0.15640986 -0.0191521  -0.01231253 -0.04009967
#  -0.04718345 -0.06695443  0.01129978 -0.00382291 -0.03593531 -0.04340772
#  -0.04578397  0.06496704  0.02318554 -0.10111573 -0.04939262 -0.08969732
#   0.05733475 -0.00784449 -0.01593396 -0.01114049 -0.09898568 -0.02952959
#   0.06491417 -0.02921497  0.01786301 -0.07599497  0.00329981  0.05612759
#   0.08308071 -0.0363443  -0.00769564 -0.14484476  0.01198043 -0.08531011
#  -0.09672397  0.02866566 -0.01757023 -0.01005484 -0.04595303 -0.03599979
#  -0.1662413   0.0097875  -0.02131353 -0.05130979 -0.02927662  0.02199732
#  -0.04174482 -0.02663122 -0.01809496  0.03586497  0.00564618 -0.03280949
#  -0.00822526 -0.03011889 -0.04650604  0.00357994 -0.03801381 -0.05808884
#  -0.0708936   0.04610728 -0.03395366 -0.00710647 -0.05397659 -0.06890164
#  -0.03367637  0.00179253  0.09210456  0.01634984 -0.0477349  -0.03906583
#  -0.07525754  0.02111736 -0.0119634  -0.00468066 -0.08622809  0.02635694
#  -0.05588849 -0.03645209 -0.02318487 -0.1025409   0.03407046 -0.00328474
#  -0.03758657 -0.02795927  0.00739031 -0.09070607  0.01593524 -0.03948076
#  -0.01611732 -0.05345972 -0.03430444 -0.08335871 -0.03673933 -0.00800499
#   0.07602609  0.00127285 -0.05317067 -0.06574486 -0.05647511 -0.05428272
#  -0.1023133  -0.0103273  -0.01258684 -0.05246289 -0.00833692 -0.03524702
#   0.03205279  0.01127638 -0.0200154  -0.07487068  0.00443543 -0.02855172
#   0.01023865  0.03354174 -0.0309303   0.00223172 -0.11885816 -0.02565361
#   0.01251496  0.06368227  0.03279493  0.00906372 -0.05273476  0.02275015
#   0.0486947  -0.03429786 -0.02601944  0.00457197  0.01080869 -0.03981805
#  -0.00614168 -0.04090038 -0.01714579 -0.17414849 -0.02040073 -0.05323761
#  -0.05698027 -0.08149914 -0.03153741 -0.04711782 -0.16693062 -0.01615852
#   0.02539943  0.00363286 -0.02730378  0.06091169 -0.10271501  0.01305124
#   0.0319092  -0.00291513 -0.03615152 -0.02554147  0.04647097 -0.0396507
#  -0.04595986 -0.02364435  0.02674059  0.04291648  0.0739886  -0.01704309
#  -0.05420781 -0.08269125 -0.04183092 -0.05854709 -0.0824964  -0.03809362
#   0.00354746  0.04749743 -0.08126266  0.04586895 -0.00774563 -0.01656144
#   0.09297501 -0.01134033  0.05890598 -0.05345475 -0.02459593 -0.09924597]
# biases2:0 [-0.17799684 -0.22971292 -0.51287556 -0.15845321 -0.1700142  -0.18355493
#  -0.1197218   0.16933219 -0.26282865 -0.10714154 -0.14980468 -0.22262685
#  -0.25185215 -0.07546178  0.46390399 -0.01623756 -0.14453627 -0.27767757
#  -0.22820221 -0.06272202  0.21671249 -0.1176869  -0.23380031 -0.16227815
#  -0.18147874 -0.11347054 -0.26647544  0.00383357 -0.12624139 -0.09439586
#  -0.27915981 -0.04603395 -0.16638313 -0.07601702 -0.05253959 -0.12687871
#  -0.11528332 -0.08625275 -0.11048803 -0.1187107   0.09023785 -0.22628118
#  -0.20047517 -0.07330263 -0.08810259  0.04672936 -0.32057503  0.24640776
#  -0.03094728 -0.05082574 -0.30193245 -0.10538699 -0.08817132 -0.05482489
#  -0.11741763  0.09009902 -0.3957721  -0.17910914 -0.26811552 -0.14941658
#  -0.01648264 -0.08826566 -0.28764117 -0.0198368   0.1132597  -0.14493373
#  -0.28867424 -0.19971891 -0.07263631 -0.26185632 -0.01010396  0.0934298
#  -0.33735728  0.28849459 -0.16558337 -0.15163307 -0.24350137 -0.08262236
#  -0.04443305 -0.12874679  0.41302326  0.06117954  0.01523116 -0.12326428
#  -0.13809489 -0.03955214 -0.19551522 -0.42215347 -0.13394256 -0.2110568
#  -0.32285064 -0.23549066 -0.08523551 -0.0853484   0.06043034 -0.120286
#  -0.00054356 -0.04002742  0.19566281 -0.27007815 -0.10217442 -0.14549333
#  -0.13142237 -0.12290745 -0.09930491  0.06673178 -0.4770337  -0.088848
#   0.21699728 -0.24507995 -0.01898335  0.21950541  0.06413862 -0.37172213
#  -0.34465352  0.09294132  0.08972454  0.0502524  -0.30052909  0.10301506
#  -0.17323671 -0.2229342   0.28162822 -0.31253526 -0.15271035  0.15697816
#  -0.11201326  0.22492905 -0.1654437  -0.16084859 -0.09496642  0.19927864
#  -0.29994789  0.17859721 -0.11210863 -0.2088446  -0.29784787 -0.14723314
#  -0.26131538 -0.0652145  -0.26667061 -0.13303062 -0.08334598 -0.17722194
#   0.22416505 -0.32313254  0.28463888  0.203218   -0.02291257 -0.1885273 ]
# biases3:0 [-0.18171646  0.0519278  -0.22836362 -0.26770777 -0.1304581  -0.1945284
#  -0.23648885 -0.17707884 -0.23698033 -0.15452191 -0.24684067 -0.04591853
#  -0.29589981 -0.19089364 -0.14515878 -0.25587189 -0.07434119 -0.23815064
#  -0.31015679 -0.06852058 -0.09087891  0.04770142 -0.24138843 -0.30326045
#  -0.23251985 -0.2282545  -0.24710612 -0.19658299 -0.16450207 -0.17732908
#  -0.15538809 -0.28210762 -0.09374536 -0.19079296 -0.22038397 -0.09074069
#  -0.10875238 -0.25848049 -0.08974275  0.02172422 -0.17828789 -0.21087612
#  -0.22873059 -0.21777451  0.01201213 -0.10287926 -0.27660915 -0.19351369
#   0.0038705  -0.16155031 -0.18065372  0.01640786 -0.12475552  0.06072174
#  -0.24765956 -0.2473978  -0.03095369 -0.09746762 -0.2437567  -0.1568307
#  -0.05232626 -0.15496705 -0.22709185 -0.13783537 -0.20953518  0.0756356
#  -0.03838709 -0.0894837  -0.16282195 -0.10659248 -0.23784202  0.02359357
#  -0.21006699 -0.18896197 -0.12659891 -0.21922392 -0.34266314 -0.09772029
#  -0.13969044 -0.0978718  -0.28162345 -0.2575095  -0.18636523 -0.16441834
#   0.09495641 -0.1615817  -0.09725659 -0.00447942 -0.2458407  -0.23655893
#  -0.25514847 -0.14955533 -0.22421615 -0.22447701 -0.26571184 -0.16938536
#  -0.10401388 -0.13823919 -0.2664004  -0.30086926 -0.07345348 -0.11486739
#   0.00713835 -0.28380996 -0.18840033  0.07432038 -0.14287099 -0.23319778
#  -0.26009491 -0.15650526 -0.00684042 -0.01123735 -0.11748154 -0.25111705
#  -0.13546269 -0.27471074 -0.2074541  -0.01680431 -0.21699664 -0.09516489
#   0.04354141 -0.24206179 -0.27011409 -0.21104099 -0.19109066 -0.17143346
#  -0.21830165 -0.21742162 -0.19670887 -0.16514623 -0.11531618 -0.11909868
#  -0.1679846  -0.09004212 -0.20638263  0.01517445 -0.09376763 -0.15453394
#  -0.07269872 -0.09298558 -0.18183707 -0.25836405 -0.1900342  -0.16669592
#  -0.24982888 -0.27032366 -0.07179294 -0.04228701 -0.16903079 -0.14617777
#   0.0164402  -0.20842601 -0.21220295 -0.15133613 -0.30029652 -0.19316293
#  -0.21382964  0.03576034 -0.23576432 -0.17072712 -0.18831792 -0.20593043
#  -0.13722613 -0.27558041  0.05062899 -0.10403215 -0.19325992 -0.15945865
#  -0.03624118 -0.10262131 -0.07189484 -0.28264597 -0.29248157 -0.05055201
#  -0.20056252 -0.33499706  0.03267454 -0.2077063  -0.06883474 -0.04363044
#  -0.09426729 -0.02492827  0.12871388 -0.18357246  0.04043331 -0.12184425
#   0.0788096  -0.11550957 -0.07900547 -0.33143768 -0.08095647 -0.10109567
#  -0.03660432 -0.20933348 -0.20172577 -0.23770747 -0.24437951 -0.20918794
#  -0.2532407  -0.33225435  0.02073884 -0.13220561  0.12939784 -0.17778741
#  -0.12318328 -0.09014352 -0.0168834  -0.29868904 -0.18641987 -0.23709133
#  -0.05214848 -0.23855241  0.09188838 -0.03439082 -0.21073575 -0.1879555
#  -0.219723   -0.10180888 -0.24370024 -0.25645289 -0.17586358 -0.20906508
#  -0.31320924 -0.18629029 -0.17786178 -0.24416424 -0.08036252 -0.25793219
#  -0.22039856 -0.20474823 -0.2355822  -0.24928337 -0.21841881 -0.28071156
#  -0.26286629 -0.21036133 -0.13684085 -0.24096446 -0.11926433 -0.26671749
#   0.01978448  0.03379754 -0.1151351  -0.26306793 -0.20977429 -0.07764695
#  -0.13958399 -0.22504607 -0.19858146 -0.19567446 -0.24772698 -0.2652224
#  -0.14213209 -0.23880789  0.00056689 -0.0711464  -0.14502822 -0.1304241
#  -0.24199475 -0.16245642 -0.09715156 -0.05190477  0.13957545  0.08978646
#  -0.26452923 -0.22605994 -0.00722977 -0.08704661  0.11366166 -0.12853499
#  -0.22266406 -0.17903571 -0.25488555 -0.27669936 -0.1095673  -0.09229168
#  -0.25027025  0.11815328 -0.19154376 -0.09056278 -0.25583291  0.0306388
#  -0.26258922 -0.01834434 -0.22934207 -0.14227346 -0.16560028 -0.25380307
#  -0.17393111 -0.19704841  0.12799557 -0.20831758 -0.24181619 -0.20616361
#   0.15829286 -0.0414685  -0.07452773 -0.27270994 -0.22523819  0.08498635]
# biases4:0 [ -1.40009124e-05  -4.88636906e-05  -2.98333453e-06  -1.28515399e-06
#   -1.22303987e-04   2.14705051e-05   4.55757885e-07  -1.82576641e-05
#    1.23430600e-05   4.06270573e-08  -3.75972922e-05  -4.44683865e-05
#    2.79740902e-07   1.07481726e-04   1.86047801e-05   1.47319251e-05
#   -5.27340380e-05  -5.59436194e-06  -1.20250149e-07   1.66520986e-04
#    1.59119918e-06   3.12859243e-06   1.47673811e-04   3.94501767e-05
#   -1.72916789e-05   6.19096312e-08   1.63696932e-05   1.93028565e-04
#    2.13707492e-04   6.15638564e-05  -4.52736625e-04   9.56040469e-10
#   -5.26023447e-04  -1.73742251e-06   1.86434234e-04   2.67367228e-04
#    3.80159108e-05   6.99023309e-04   5.72706573e-04   1.05400756e-03
#    2.04121182e-03   1.97116123e-03   1.59519690e-03   7.55385205e-04
#    1.61917775e-03   1.45382306e-03   8.76919250e-04   1.19098264e-03
#    1.82919845e-04  -7.24324636e-05   3.40581460e-06  -2.34356587e-04
#    1.86003138e-06  -8.29287528e-10   8.52731682e-06   1.52512484e-05
#   -8.57227860e-06  -1.11666159e-05   3.17073100e-05   2.44759904e-05
#    1.65981346e-05   8.70669537e-05   5.75014274e-04   1.43360044e-03
#    1.74166204e-03   2.88321264e-03   7.89285265e-03   9.27082263e-03
#    9.41050425e-03   1.11733470e-02   1.28929373e-02   1.26589062e-02
#    1.51579008e-02   1.48652121e-02   9.14111361e-03   4.87631327e-03
#   -4.36070346e-04  -7.54270703e-04   9.07036825e-04   5.14916959e-04
#   -4.05827086e-05   3.65464017e-04   3.57033641e-05  -1.73267586e-06
#   -2.67199084e-06  -5.83539349e-06  -3.02957051e-06  -1.01621181e-05
#    1.96164929e-05   3.68983019e-04   1.27190875e-03   1.40988408e-03
#    2.35664379e-03   5.09479176e-03   9.43186972e-03   7.38037564e-03
#    5.37683722e-03   1.98434293e-03   4.69721435e-03   1.17411250e-02
#    1.98369343e-02   2.08484270e-02   1.14423772e-02   6.23638928e-03
#   -1.58181530e-03  -4.13344242e-04   2.21435027e-03   1.92584912e-03
#    8.74310441e-04   5.14635351e-04   1.11957394e-04   1.70044477e-05
#   -2.09090672e-06   6.58174977e-04  -6.22395601e-05   2.60098714e-05
#    5.91054675e-04   1.84133183e-03   2.84160208e-03   2.52046855e-03
#    2.16132356e-03   5.92449121e-03   1.47261936e-03   1.52175967e-03
#    3.42934974e-03   4.70861001e-03   1.24227498e-02   2.41313595e-02
#    2.98986305e-02   2.44541671e-02   1.35592250e-02   1.16235651e-02
#    6.35517668e-03   6.16747886e-03   5.35493437e-03   6.54758792e-03
#    3.43926763e-03   8.58960324e-04   2.74416379e-04   4.88223341e-05
#    1.48843185e-06   3.10446158e-05   3.60673621e-05   3.46504414e-04
#    1.27850648e-03   8.96595651e-04  -4.40169126e-04   1.05283316e-03
#    4.99172020e-04  -4.93624620e-03  -9.74597037e-03   4.65337466e-03
#    2.65307091e-02   4.54003923e-02   6.18665330e-02   7.69444332e-02
#    6.44763485e-02   4.75327224e-02   4.29225601e-02   3.70336361e-02
#    2.41215695e-02   4.93051764e-03  -1.25175086e-03   7.43058790e-03
#    9.58417077e-03   5.72582008e-03   1.71976956e-03   5.05200624e-05
#    1.33595154e-06  -9.67859705e-06   2.01911331e-04   9.22664767e-04
#   -1.16804172e-03  -4.94560460e-03  -5.50432736e-03  -6.74528116e-03
#   -1.45424278e-02  -1.18119223e-02   1.94388616e-04   2.54882742e-02
#    5.55750579e-02   7.64220357e-02   9.73504037e-02   1.03000648e-01
#    8.41089115e-02   7.22586215e-02   6.95816800e-02   6.42702356e-02
#    3.34881581e-02   1.07911974e-03  -8.87608901e-03   4.39001387e-03
#    1.62311811e-02   9.96935274e-03   2.57016812e-03   4.99569171e-04
#    3.30595049e-06  -4.39236192e-06   1.63026666e-03   1.63877360e-03
#   -4.12472757e-03  -1.34615721e-02  -2.53490712e-02  -3.31697389e-02
#   -2.42776331e-02  -6.70857681e-03   2.24043988e-02   5.22756614e-02
#    6.88107684e-02   8.47985968e-02   1.04607813e-01   1.03611231e-01
#    1.05556987e-01   9.60155129e-02   8.76257345e-02   6.55924827e-02
#    3.28531489e-02   6.26779906e-03  -1.19857397e-02  -1.53997319e-03
#    1.89155266e-02   1.11177117e-02   1.93346653e-03   2.41204179e-04
#   -1.07124906e-05   4.72934393e-04   3.35776736e-03   3.48377693e-03
#   -3.34903621e-03  -2.09164079e-02  -4.08733003e-02  -4.49858010e-02
#   -2.11310238e-02   1.21741667e-02   4.86453623e-02   6.21036738e-02
#    7.18309879e-02   8.29564333e-02   9.10519287e-02   7.83623308e-02
#    7.56729022e-02   9.37923044e-02   8.59567299e-02   4.99063283e-02
#    4.18149121e-02   2.41637435e-02  -5.55045670e-03  -9.48006404e-04
#    1.78349949e-02   1.16256271e-02   1.03399903e-03   3.67836124e-04
#    1.51590692e-04   8.02982948e-04   3.23132309e-03   4.15299507e-03
#   -1.68834068e-03  -1.86820850e-02  -3.52839567e-02  -2.77551971e-02
#    4.99416934e-03   4.04988937e-02   5.63686639e-02   6.82634041e-02
#    7.48873651e-02   6.78898171e-02   5.24145067e-02   4.45157997e-02
#    6.28229827e-02   8.17785561e-02   7.63447285e-02   4.11061645e-02
#    4.59510349e-02   2.97880974e-02  -2.37402925e-03  -7.94409495e-03
#    5.69662638e-03   7.50751747e-03   1.53287873e-03   2.54069222e-04
#    1.90558436e-04   6.94501039e-04   3.27281398e-03   4.44108481e-03
#    1.33210397e-03  -8.94055329e-03  -1.76843442e-02  -7.62384897e-03
#    2.99205706e-02   4.81971242e-02   5.72013557e-02   7.06299394e-02
#    7.47898296e-02   4.42382134e-02   3.17707285e-02   2.74967309e-02
#    4.95506190e-02   8.15225840e-02   7.07511157e-02   3.80227230e-02
#    4.43502367e-02   2.21543722e-02  -4.85021574e-03  -4.27298481e-03
#    3.23335058e-03   4.10278328e-03   2.72606825e-03   2.73611979e-04
#    7.18851225e-05   8.03556934e-04   2.63697444e-03   4.34658909e-03
#    6.19907305e-03   1.21461926e-05  -7.26698386e-03   3.63965309e-03
#    3.64744216e-02   5.09667471e-02   5.35526350e-02   6.16648719e-02
#    5.69807068e-02   2.82712597e-02   3.87052409e-02   3.77696380e-02
#    4.70417328e-02   8.06641504e-02   7.03219995e-02   4.16772887e-02
#    3.07389759e-02   9.70410742e-03   8.42479989e-04   5.11463778e-03
#    7.14015961e-03   2.13338225e-03   1.28212036e-03   1.74352273e-04
#   -2.59997387e-06   6.74805429e-04   2.41026166e-03   4.74118581e-03
#    6.65237149e-03   2.99125677e-03  -5.64325182e-03   9.24455747e-03
#    3.94332409e-02   4.41548899e-02   4.20175008e-02   4.85080592e-02
#    3.05612348e-02   1.15028443e-02   6.01052642e-02   4.74736765e-02
#    5.22460118e-02   9.23062265e-02   6.69693276e-02   3.17293331e-02
#    1.55727956e-02   8.99334345e-03   7.47437868e-03   1.68090351e-02
#    1.47820627e-02   1.90048199e-03   9.16564604e-04   2.33612023e-04
#    2.13184148e-06   7.65685458e-04   1.38912746e-03   2.59810174e-03
#    6.12907624e-03   3.65106366e-03  -1.61889475e-05   1.82093140e-02
#    3.49488780e-02   3.17386985e-02   4.18240502e-02   5.10476790e-02
#    2.20109727e-02   3.51418108e-02   8.51611942e-02   5.89655526e-02
#    6.22541644e-02   1.02256231e-01   6.82498887e-02   2.87256651e-02
#    1.86838564e-02   1.29728280e-02   9.14565567e-03   1.95863564e-02
#    1.76419392e-02   2.62198620e-03   1.16500282e-03   7.39982526e-04
#    4.96441771e-07   3.10053059e-04   6.80896745e-04   1.84846821e-03
#    3.04617314e-03   5.77537855e-03   3.32024670e-03   1.55274058e-02
#    3.19276080e-02   3.01300734e-02   4.60038185e-02   6.01147115e-02
#    3.93384621e-02   7.78734088e-02   1.15603246e-01   8.93124118e-02
#    9.73500237e-02   1.18316844e-01   6.24690168e-02   2.62072384e-02
#    2.72716470e-02   1.40190190e-02   1.08654387e-02   2.07524598e-02
#    1.47001259e-02   2.17020232e-03   6.03169785e-04   1.08354179e-04
#    7.50538402e-06   1.80409934e-05   6.55630371e-04   3.14418902e-03
#    3.55588878e-03   9.08823626e-04  -4.51376545e-04   1.43178897e-02
#    2.96291094e-02   2.25629173e-02   2.47217901e-02   3.14769149e-02
#    2.70594284e-02   8.49106386e-02   1.21392652e-01   8.90411213e-02
#    1.00721776e-01   1.07967600e-01   4.78974245e-02   2.32187603e-02
#    2.33796183e-02   7.40392879e-03   3.43282078e-03   1.36505086e-02
#    1.16993254e-02   2.42533023e-03   5.07258403e-04   1.35112175e-04
#    8.20165005e-05  -3.02789995e-05   7.07786530e-04   2.93452316e-03
#    2.81191454e-03  -3.34323558e-04  -2.14391737e-04   1.74390431e-02
#    1.32959317e-02  -1.02376600e-03   2.06569233e-03   1.57198422e-02
#    2.54130624e-02   7.07351565e-02   8.76162052e-02   6.97344914e-02
#    9.16549116e-02   8.32195133e-02   4.41211239e-02   2.12179888e-02
#    9.18012112e-03  -7.53390556e-03  -2.27293512e-03   8.30515567e-03
#    3.27303889e-03   2.71154358e-03   1.98872108e-03   4.87796904e-04
#    4.35658694e-05   3.53719224e-05   1.24863733e-03   4.01169388e-03
#    2.76464992e-03   6.76134368e-06   3.70575883e-03   1.75671838e-02
#    1.53465727e-02   4.72256308e-03   2.23830976e-02   4.15834412e-02
#    4.77673225e-02   6.44865334e-02   7.30405599e-02   6.55913055e-02
#    7.80090839e-02   6.20306656e-02   4.38969359e-02   7.73804402e-03
#   -6.28742576e-03  -5.41539863e-03  -1.32228853e-03  -3.95571487e-03
#   -3.37774074e-03  -3.15833226e-04   7.38852599e-04   3.15258774e-04
#    8.54613154e-06  -1.73210865e-04   1.49165012e-03   5.69882384e-03
#    3.00774537e-03   1.10439060e-03   1.39380470e-02   2.93770768e-02
#    3.51553038e-02   2.59859674e-02   4.75679711e-02   6.22600578e-02
#    6.47974387e-02   7.56087676e-02   8.51008594e-02   7.83155635e-02
#    8.70913491e-02   6.59560785e-02   3.92451771e-02  -2.25374452e-03
#   -4.33901139e-03   2.41733924e-03  -6.78319717e-03  -1.23175513e-02
#   -6.85982080e-03   4.89799306e-04   1.05320732e-03   3.01294262e-04
#    1.18324606e-05   4.55050613e-04   1.59145775e-03   6.19544741e-03
#    2.35461374e-03  -4.12048353e-03   1.58476904e-02   3.57830487e-02
#    3.93265896e-02   3.15479562e-02   3.79169099e-02   5.50252683e-02
#    6.87696040e-02   8.86824280e-02   1.07564919e-01   1.06798761e-01
#    9.69092548e-02   6.39254525e-02   2.57709306e-02  -2.11493485e-03
#    8.78509693e-03   3.46897310e-03  -1.92847345e-02  -1.90510433e-02
#   -9.68360715e-03  -1.17640675e-03   3.48478439e-04   7.22553750e-06
#   -6.82138079e-07   1.15613002e-04   2.12526624e-03   7.09206006e-03
#   -1.10952510e-03  -8.86827894e-03   1.97584368e-03   2.32391302e-02
#    3.22335362e-02   2.07873732e-02   1.88051593e-02   4.98975180e-02
#    8.46088827e-02   1.11106038e-01   1.11371815e-01   1.11997165e-01
#    8.90790820e-02   5.48737571e-02   2.68611927e-02   1.13755101e-02
#    3.90498503e-03  -1.76177360e-02  -2.95427628e-02  -2.51981560e-02
#   -1.07150339e-02  -1.17012777e-03   8.50824057e-04   2.15258740e-04
#   -1.29930850e-05   5.31504265e-05   1.84248167e-03   6.38866518e-03
#    1.48486637e-04  -4.44697170e-03   3.39999120e-03   1.26264384e-02
#    2.78890748e-02   2.65297480e-02   3.19720209e-02   6.20045029e-02
#    8.18942562e-02   8.73545036e-02   8.44118446e-02   8.34080651e-02
#    7.56348446e-02   5.43444380e-02   2.24628001e-02   2.89255579e-04
#   -2.05048695e-02  -3.51891220e-02  -3.30141969e-02  -1.71812065e-02
#   -6.67535001e-03  -2.08629062e-03  -4.67175414e-06  -6.56745979e-05
#   -1.18785363e-04  -7.77000605e-06   1.29219959e-03   3.68507882e-03
#    4.27875668e-03   4.70786495e-03   6.73090620e-03   1.32801719e-02
#    2.19113752e-02   4.34392393e-02   6.88555688e-02   9.47342366e-02
#    9.04089287e-02   7.72129595e-02   7.60816559e-02   7.03791305e-02
#    7.11590499e-02   3.62980552e-02   1.35625410e-03  -2.29120404e-02
#   -3.46366763e-02  -3.31148356e-02  -2.04227287e-02  -8.90710764e-03
#   -3.45698604e-03  -1.23813370e-04  -2.18456007e-05  -3.17793660e-04
#    1.22510057e-04  -2.06228628e-06   8.30600853e-04   2.59498716e-03
#    5.86331310e-03   9.74485837e-03   1.43570472e-02   1.84156485e-02
#    1.63148306e-02   2.84046624e-02   5.36624752e-02   7.22889528e-02
#    6.86707571e-02   6.52292371e-02   6.31056577e-02   5.54500967e-02
#    3.74205373e-02   1.63465217e-02  -6.97906176e-03  -1.39526017e-02
#   -1.29999071e-02  -5.63583290e-03  -1.51084224e-03  -1.23513862e-04
#   -5.06259210e-04   1.38391144e-04  -8.35319952e-07  -3.58994912e-05
#    2.36061305e-06  -5.52658435e-08   1.60539916e-04   7.05147570e-04
#    3.26349307e-03   7.89614953e-03   1.26022100e-02   1.05906501e-02
#    1.10013243e-02   8.37379228e-03   1.50970379e-02   1.98752359e-02
#    1.39658777e-02   1.84044745e-02   2.75749471e-02   3.08591221e-02
#    2.42241435e-02   1.68487206e-02   9.35555622e-03   4.17135330e-03
#    3.39750922e-03   3.58991325e-03   2.97195883e-03   2.12316820e-03
#    5.44180104e-04   1.99868125e-04   4.77821886e-04  -1.16518633e-04
#    3.79897688e-06   1.63765522e-04   5.62980167e-05   5.38109307e-05
#    1.18259620e-03   2.26097438e-03   4.35522245e-03   4.05654870e-03
#    1.23544708e-02   1.35921072e-02   1.26669463e-02   1.09095927e-02
#    1.61221847e-02   2.76536029e-02   2.91203391e-02   2.75147650e-02
#    2.75177117e-02   2.27827094e-02   1.46531323e-02   9.14123654e-03
#    3.41924746e-03   3.22455540e-03   1.76332961e-03   8.65681039e-04
#   -4.94760970e-05   2.19163376e-05   2.52726284e-04   9.39451347e-05
#   -1.02025922e-03  -6.80490484e-05  -1.47868341e-05   1.28623587e-05
#    2.69154232e-04   6.40071929e-04   1.02904858e-03   3.79269710e-03
#    4.93508205e-03   8.06282554e-03   1.27179949e-02   1.64801218e-02
#    2.25051101e-02   2.65501291e-02   2.46959236e-02   2.17825882e-02
#    1.87313091e-02   1.58339962e-02   1.05224000e-02   3.85768665e-03
#    7.19949370e-04   1.57807546e-03   5.71740849e-04   1.92320746e-04
#   -3.67198300e-05   4.23805723e-05   1.42832578e-04  -6.50560878e-06
#    1.11106092e-05  -2.59043481e-05  -1.18780597e-04  -8.49291882e-06
#    2.85395690e-05   3.29726492e-04   4.78708185e-04   7.95514497e-04
#    4.30797518e-04   1.11380694e-04   1.16982718e-03   2.52082385e-03
#    3.72677832e-03   4.75251675e-03   6.69775810e-03   5.58602903e-03
#    5.98982815e-03   6.14236249e-03   3.14661139e-03   8.28728429e-04
#    5.69054857e-04   3.49566515e-04   4.53792221e-04   1.01491780e-04
#    1.29882437e-05  -6.92450215e-07   9.12891664e-06  -7.46241221e-06]

# %%
with tf.Session() as sess:
    saver.restore(sess, "./my_model_one_at_a_time.ckpt") 
    weights1_val = weights1.eval()

for i in range(5):
    plt.subplot(1, 5, i + 1)
    plot_image(weights1_val.T[i])

save_fig("extracted_features_plot") 
plt.show()
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_one_at_a_time.ckpt
# Saving figure extracted_features_plot

# %%
reset_graph()

n_inputs = 28 * 28
n_hidden1 = 300
n_hidden2 = 150
n_outputs = 10

learning_rate = 0.01
l2_reg = 0.0005

activation = tf.nn.elu
regularizer = tf.contrib.layers.l2_regularizer(l2_reg)
initializer = tf.contrib.layers.variance_scaling_initializer()

X = tf.placeholder(tf.float32, shape=[None, n_inputs])
y = tf.placeholder(tf.int32, shape=[None])

weights1_init = initializer([n_inputs, n_hidden1])
weights2_init = initializer([n_hidden1, n_hidden2])
weights3_init = initializer([n_hidden2, n_hidden3])

weights1 = tf.Variable(weights1_init, dtype=tf.float32, name="weights1")
weights2 = tf.Variable(weights2_init, dtype=tf.float32, name="weights2")
weights3 = tf.Variable(weights3_init, dtype=tf.float32, name="weights3")

biases1 = tf.Variable(tf.zeros(n_hidden1), name="biases1")
biases2 = tf.Variable(tf.zeros(n_hidden2), name="biases2")
biases3 = tf.Variable(tf.zeros(n_hidden3), name="biases3")

hidden1 = activation(tf.matmul(X, weights1) + biases1)
hidden2 = activation(tf.matmul(hidden1, weights2) + biases2)
logits = tf.matmul(hidden2, weights3) + biases3

cross_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
reg_loss = regularizer(weights1) + regularizer(weights2) + regularizer(weights3)
loss = cross_entropy + reg_loss
optimizer = tf.train.AdamOptimizer(learning_rate)
training_op = optimizer.minimize(loss)

correct = tf.nn.in_top_k(logits, y, 1)
accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

init = tf.global_variables_initializer()
pretrain_saver = tf.train.Saver([weights1, weights2, biases1, biases2])
saver = tf.train.Saver()

# %%
n_epochs = 4
batch_size = 150
n_labeled_instances = 20000

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        n_batches = n_labeled_instances // batch_size
        for iteration in range(n_batches):
            print("\r{}%".format(100 * iteration // n_batches), end="")
            sys.stdout.flush()
            indices = rnd.permutation(n_labeled_instances)[:batch_size]
            X_batch, y_batch = mnist.train.images[indices], mnist.train.labels[indices]
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        accuracy_val = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        print("\r{}".format(epoch), "Train accuracy:", accuracy_val, end=" ")
        saver.save(sess, "./my_model_supervised.ckpt")
        accuracy_val = accuracy.eval(feed_dict={X: mnist.test.images, y: mnist.test.labels})
        print("Test accuracy:", accuracy_val)
# Out:
# 0 Train accuracy: 0.94 Test accuracy: 0.9185
# 1 Train accuracy: 0.96 Test accuracy: 0.9447
# 2 Train accuracy: 0.96 Test accuracy: 0.9487
# 3 Train accuracy: 0.986667 Test accuracy: 0.9467

# %%
n_epochs = 4
batch_size = 150
n_labeled_instances = 20000

#training_op = optimizer.minimize(loss, var_list=[weights3, biases3])  # Freeze layers 1 and 2 (optional)

with tf.Session() as sess:
    init.run()
    pretrain_saver.restore(sess, "./my_model_cache_frozen.ckpt")
    
    tvars = tf.trainable_variables()
    
    tvars_vals = sess.run(tvars)
    
    for epoch in range(n_epochs):
        n_batches = n_labeled_instances // batch_size
        for iteration in range(n_batches):
            print("\r{}%".format(100 * iteration // n_batches), end="")
            sys.stdout.flush()
            indices = rnd.permutation(n_labeled_instances)[:batch_size]
            X_batch, y_batch = mnist.train.images[indices], mnist.train.labels[indices]
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        accuracy_val = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        print("\r{}".format(epoch), "Train accuracy:", accuracy_val, end="\t")
        saver.save(sess, "./my_model_supervised_pretrained.ckpt")
        accuracy_val = accuracy.eval(feed_dict={X: mnist.test.images, y: mnist.test.labels})
        print("Test accuracy:", accuracy_val)
# Out:
# INFO:tensorflow:Restoring parameters from ./my_model_cache_frozen.ckpt
# 0 Train accuracy: 0.933333	Test accuracy: 0.9275
# 19% Train accuracy: 0.966667	Test accuracy: 0.9479
# 2 Train accuracy: 0.986667	Test accuracy: 0.9354
# 3 Train accuracy: 0.98	Test accuracy: 0.9463

# %%
reset_graph()

n_inputs = 28 * 28
n_hidden1 = 1000  # sparse codings
n_outputs = n_inputs

# %%
def kl_divergence(p, q):
    # Kullback Leibler divergence
    return p * tf.log(p / q) + (1 - p) * tf.log((1 - p) / (1 - q))

learning_rate = 0.01
sparsity_target = 0.1
sparsity_weight = 0.2

X = tf.placeholder(tf.float32, shape=[None, n_inputs])            

hidden1 = tf.layers.dense(X, n_hidden1, activation=tf.nn.sigmoid) 
outputs = tf.layers.dense(hidden1, n_outputs)                     

hidden1_mean = tf.reduce_mean(hidden1, axis=0) # batch mean
sparsity_loss = tf.reduce_sum(kl_divergence(sparsity_target, hidden1_mean))
reconstruction_loss = tf.reduce_mean(tf.square(outputs - X)) # MSE
loss = reconstruction_loss + sparsity_weight * sparsity_loss

optimizer = tf.train.AdamOptimizer(learning_rate)
training_op = optimizer.minimize(loss)

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
n_epochs = 100
batch_size = 1000

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        n_batches = mnist.train.num_examples // batch_size
        for iteration in range(n_batches):
            print("\r{}%".format(100 * iteration // n_batches), end="")
            sys.stdout.flush()
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch})
        reconstruction_loss_val, sparsity_loss_val, loss_val = sess.run([reconstruction_loss, sparsity_loss, loss], feed_dict={X: X_batch})
        print("\r{}".format(epoch), "Train MSE:", reconstruction_loss_val, "\tSparsity loss:", sparsity_loss_val, "\tTotal loss:", loss_val)
        saver.save(sess, "./my_model_sparse.ckpt")
# Out:
# 0 Train MSE: 0.131474 	Sparsity loss: 0.215301 	Total loss: 0.174534
# 1 Train MSE: 0.0592777 	Sparsity loss: 0.151371 	Total loss: 0.0895519
# 2 Train MSE: 0.051831 	Sparsity loss: 0.0230559 	Total loss: 0.0564421
# 3 Train MSE: 0.0490905 	Sparsity loss: 0.096128 	Total loss: 0.0683161
# 4 Train MSE: 0.0455875 	Sparsity loss: 0.487191 	Total loss: 0.143026
# 5 Train MSE: 0.0409968 	Sparsity loss: 0.0135964 	Total loss: 0.0437161
# 6 Train MSE: 0.0381746 	Sparsity loss: 0.0182552 	Total loss: 0.0418256
# 7 Train MSE: 0.0367286 	Sparsity loss: 0.00857303 	Total loss: 0.0384432
# 8 Train MSE: 0.0332256 	Sparsity loss: 0.0206892 	Total loss: 0.0373634
# 9 Train MSE: 0.0316032 	Sparsity loss: 0.206591 	Total loss: 0.0729215
# 10 Train MSE: 0.0274669 	Sparsity loss: 0.0500361 	Total loss: 0.0374741
# 11 Train MSE: 0.0249979 	Sparsity loss: 0.0912406 	Total loss: 0.043246
# 12 Train MSE: 0.0232693 	Sparsity loss: 0.083458 	Total loss: 0.0399609
# 13 Train MSE: 0.0222022 	Sparsity loss: 0.0220444 	Total loss: 0.026611
# 14 Train MSE: 0.02032 	Sparsity loss: 0.154329 	Total loss: 0.0511858
# 15 Train MSE: 0.018981 	Sparsity loss: 0.0707978 	Total loss: 0.0331405
# 16 Train MSE: 0.0217773 	Sparsity loss: 0.0444375 	Total loss: 0.0306648
# 17 Train MSE: 0.0174739 	Sparsity loss: 0.0858982 	Total loss: 0.0346536
# 18 Train MSE: 0.0172321 	Sparsity loss: 0.108446 	Total loss: 0.0389213
# 19 Train MSE: 0.0173158 	Sparsity loss: 0.146542 	Total loss: 0.0466241
# 20 Train MSE: 0.0169623 	Sparsity loss: 0.0416837 	Total loss: 0.025299
# 21 Train MSE: 0.0158787 	Sparsity loss: 0.0635964 	Total loss: 0.028598
# 22 Train MSE: 0.0154191 	Sparsity loss: 0.0713719 	Total loss: 0.0296935
# 23 Train MSE: 0.0148601 	Sparsity loss: 0.0320765 	Total loss: 0.0212754
# 24 Train MSE: 0.0148455 	Sparsity loss: 0.0544968 	Total loss: 0.0257449
# 25 Train MSE: 0.0185334 	Sparsity loss: 0.356371 	Total loss: 0.0898076
# 26 Train MSE: 0.0144667 	Sparsity loss: 0.0504135 	Total loss: 0.0245494
# 27 Train MSE: 0.0143269 	Sparsity loss: 0.110161 	Total loss: 0.0363591
# 28 Train MSE: 0.0146201 	Sparsity loss: 0.0793578 	Total loss: 0.0304916
# 29 Train MSE: 0.0143691 	Sparsity loss: 0.0890892 	Total loss: 0.0321869
# 30 Train MSE: 0.0137555 	Sparsity loss: 0.079756 	Total loss: 0.0297067
# 31 Train MSE: 0.0154454 	Sparsity loss: 0.0704601 	Total loss: 0.0295374
# 32 Train MSE: 0.0129973 	Sparsity loss: 0.183758 	Total loss: 0.0497489
# 33 Train MSE: 0.0145843 	Sparsity loss: 0.114966 	Total loss: 0.0375775
# 34 Train MSE: 0.0133177 	Sparsity loss: 0.129487 	Total loss: 0.0392151
# 35 Train MSE: 0.0165072 	Sparsity loss: 0.164215 	Total loss: 0.0493502
# 36 Train MSE: 0.0130173 	Sparsity loss: 0.0665484 	Total loss: 0.026327
# 37 Train MSE: 0.0129489 	Sparsity loss: 0.0614209 	Total loss: 0.0252331
# 38 Train MSE: 0.0123283 	Sparsity loss: 0.0891008 	Total loss: 0.0301485
# 39 Train MSE: 0.0133527 	Sparsity loss: 0.1172 	Total loss: 0.0367927
# 40 Train MSE: 0.0120522 	Sparsity loss: 0.189853 	Total loss: 0.0500228
# 41 Train MSE: 0.0128057 	Sparsity loss: 0.103548 	Total loss: 0.0335153
# 42 Train MSE: 0.0133555 	Sparsity loss: 0.067471 	Total loss: 0.0268497
# 43 Train MSE: 0.0119571 	Sparsity loss: 0.0750487 	Total loss: 0.0269668
# 44 Train MSE: 0.0135463 	Sparsity loss: 0.104643 	Total loss: 0.034475
# 45 Train MSE: 0.0134023 	Sparsity loss: 0.256893 	Total loss: 0.0647809
# 46 Train MSE: 0.012537 	Sparsity loss: 0.249704 	Total loss: 0.0624778
# 47 Train MSE: 0.0127767 	Sparsity loss: 0.23051 	Total loss: 0.0588786
# 48 Train MSE: 0.0139129 	Sparsity loss: 0.338157 	Total loss: 0.0815444
# 49 Train MSE: 0.0130545 	Sparsity loss: 0.263895 	Total loss: 0.0658335
# 50 Train MSE: 0.012626 	Sparsity loss: 0.114772 	Total loss: 0.0355804
# 51 Train MSE: 0.0130111 	Sparsity loss: 0.190433 	Total loss: 0.0510976
# 52 Train MSE: 0.0117721 	Sparsity loss: 0.125377 	Total loss: 0.0368475
# 53 Train MSE: 0.0112008 	Sparsity loss: 0.123562 	Total loss: 0.0359132
# 54 Train MSE: 0.0117055 	Sparsity loss: 0.218702 	Total loss: 0.0554459
# 55 Train MSE: 0.0117626 	Sparsity loss: 0.30735 	Total loss: 0.0732326
# 56 Train MSE: 0.0121517 	Sparsity loss: 0.404722 	Total loss: 0.0930961
# 57 Train MSE: 0.0123029 	Sparsity loss: 0.218934 	Total loss: 0.0560897
# 58 Train MSE: 0.014598 	Sparsity loss: 0.312366 	Total loss: 0.0770712
# 59 Train MSE: 0.0126605 	Sparsity loss: 0.12362 	Total loss: 0.0373846
# 60 Train MSE: 0.0120662 	Sparsity loss: 0.274255 	Total loss: 0.0669172
# 61 Train MSE: 0.014254 	Sparsity loss: 0.324745 	Total loss: 0.0792031
# 62 Train MSE: 0.0224937 	Sparsity loss: 0.354737 	Total loss: 0.0934412
# 63 Train MSE: 0.0150114 	Sparsity loss: 0.397787 	Total loss: 0.0945689
# 64 Train MSE: 0.0118689 	Sparsity loss: 0.0900406 	Total loss: 0.0298771
# 65 Train MSE: 0.0121746 	Sparsity loss: 0.303452 	Total loss: 0.0728651
# 66 Train MSE: 0.0135836 	Sparsity loss: 0.20514 	Total loss: 0.0546116
# 67 Train MSE: 0.0167307 	Sparsity loss: 0.50938 	Total loss: 0.118607
# 68 Train MSE: 0.0204344 	Sparsity loss: 0.327541 	Total loss: 0.0859427
# 69 Train MSE: 0.0127728 	Sparsity loss: 0.313537 	Total loss: 0.0754802
# 70 Train MSE: 0.0139947 	Sparsity loss: 0.335787 	Total loss: 0.081152
# 71 Train MSE: 0.0128061 	Sparsity loss: 0.371875 	Total loss: 0.0871812
# 72 Train MSE: 0.0163708 	Sparsity loss: 0.426852 	Total loss: 0.101741
# 73 Train MSE: 0.0215003 	Sparsity loss: 0.14884 	Total loss: 0.0512683
# 74 Train MSE: 0.0213771 	Sparsity loss: 0.204063 	Total loss: 0.0621898
# 75 Train MSE: 0.026179 	Sparsity loss: 0.499088 	Total loss: 0.125997
# 76 Train MSE: 0.0162182 	Sparsity loss: 0.169623 	Total loss: 0.0501428
# 77 Train MSE: 0.0125465 	Sparsity loss: 0.263842 	Total loss: 0.0653148
# 78 Train MSE: 0.0171345 	Sparsity loss: 0.220597 	Total loss: 0.061254
# 79 Train MSE: 0.0126934 	Sparsity loss: 0.0928667 	Total loss: 0.0312667
# 80 Train MSE: 0.013452 	Sparsity loss: 0.631762 	Total loss: 0.139804
# 81 Train MSE: 0.0267655 	Sparsity loss: 0.667588 	Total loss: 0.160283
# 82 Train MSE: 0.0156609 	Sparsity loss: 0.360537 	Total loss: 0.0877684
# 83 Train MSE: 0.0300554 	Sparsity loss: 0.695802 	Total loss: 0.169216
# 84 Train MSE: 0.0136167 	Sparsity loss: 0.172015 	Total loss: 0.0480196
# 85 Train MSE: 0.0162223 	Sparsity loss: 0.280679 	Total loss: 0.0723581
# 86 Train MSE: 0.0282539 	Sparsity loss: 1.00914 	Total loss: 0.230082
# 87 Train MSE: 0.0137065 	Sparsity loss: 0.380872 	Total loss: 0.089881
# 88 Train MSE: 0.012728 	Sparsity loss: 0.165009 	Total loss: 0.0457298
# 89 Train MSE: 0.0147736 	Sparsity loss: 0.3212 	Total loss: 0.0790135
# 90 Train MSE: 0.036193 	Sparsity loss: 0.21913 	Total loss: 0.080019
# 91 Train MSE: 0.0186897 	Sparsity loss: 0.220734 	Total loss: 0.0628366
# 92 Train MSE: 0.0138925 	Sparsity loss: 0.120257 	Total loss: 0.0379439
# 93 Train MSE: 0.0282088 	Sparsity loss: 0.12606 	Total loss: 0.0534208
# 94 Train MSE: 0.0156982 	Sparsity loss: 0.490325 	Total loss: 0.113763
# 95 Train MSE: 0.0128071 	Sparsity loss: 0.120436 	Total loss: 0.0368944
# 96 Train MSE: 0.0167276 	Sparsity loss: 0.263611 	Total loss: 0.0694497
# 97 Train MSE: 0.0161883 	Sparsity loss: 0.688832 	Total loss: 0.153955
# 98 Train MSE: 0.0117589 	Sparsity loss: 0.317297 	Total loss: 0.0752183
# 99 Train MSE: 0.0245427 	Sparsity loss: 0.327673 	Total loss: 0.0900772

# %%
reset_graph()

from functools import partial

n_inputs = 28 * 28
n_hidden1 = 500
n_hidden2 = 500
n_hidden3 = 20  # codings
n_hidden4 = n_hidden2
n_hidden5 = n_hidden1
n_outputs = n_inputs
learning_rate = 0.001

initializer = tf.contrib.layers.variance_scaling_initializer()

my_dense_layer = partial(
    tf.layers.dense,
    activation=tf.nn.elu,
    kernel_initializer=initializer)

X = tf.placeholder(tf.float32, [None, n_inputs])
hidden1 = my_dense_layer(X, n_hidden1)
hidden2 = my_dense_layer(hidden1, n_hidden2)
hidden3_mean = my_dense_layer(hidden2, n_hidden3, activation=None)
hidden3_sigma = my_dense_layer(hidden2, n_hidden3, activation=None)
noise = tf.random_normal(tf.shape(hidden3_sigma), dtype=tf.float32)
hidden3 = hidden3_mean + hidden3_sigma * noise
hidden4 = my_dense_layer(hidden3, n_hidden4)
hidden5 = my_dense_layer(hidden4, n_hidden5)
logits = my_dense_layer(hidden5, n_outputs, activation=None)
outputs = tf.sigmoid(logits)

xentropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=X, logits=logits)
reconstruction_loss = tf.reduce_sum(xentropy)

# %%
eps = 1e-10 # smoothing term to avoid computing log(0) which is NaN
latent_loss = 0.5 * tf.reduce_sum(
    tf.square(hidden3_sigma) + tf.square(hidden3_mean)
    - 1 - tf.log(eps + tf.square(hidden3_sigma)))

# %%
loss = reconstruction_loss + latent_loss

optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
n_epochs = 50
batch_size = 150

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        n_batches = mnist.train.num_examples // batch_size
        for iteration in range(n_batches):
            print("\r{}%".format(100 * iteration // n_batches), end="")
            sys.stdout.flush()
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch})
        loss_val, reconstruction_loss_val, latent_loss_val = sess.run([loss, reconstruction_loss, latent_loss], feed_dict={X: X_batch})
        print("\r{}".format(epoch), "Train total loss:", loss_val, "\tReconstruction loss:", reconstruction_loss_val, "\tLatent loss:", latent_loss_val)
        saver.save(sess, "./my_model_variational.ckpt")
# Out:
# 0 Train total loss: 37329.2 	Reconstruction loss: 24752.0 	Latent loss: 12577.2
# 1 Train total loss: 27862.8 	Reconstruction loss: 22940.8 	Latent loss: 4922.01
# 2 Train total loss: 33451.6 	Reconstruction loss: 24956.7 	Latent loss: 8494.88
# 3 Train total loss: 26332.3 	Reconstruction loss: 22116.7 	Latent loss: 4215.63
# 4 Train total loss: 22890.8 	Reconstruction loss: 19555.6 	Latent loss: 3335.16
# 5 Train total loss: 26012.7 	Reconstruction loss: 20393.3 	Latent loss: 5619.38
# 6 Train total loss: 27732.7 	Reconstruction loss: 20685.3 	Latent loss: 7047.35
# 79% Train total loss: 19750.9 	Reconstruction loss: 16613.8 	Latent loss: 3137.07
# 8 Train total loss: 18259.6 	Reconstruction loss: 15323.3 	Latent loss: 2936.32
# 9 Train total loss: 17937.6 	Reconstruction loss: 14881.3 	Latent loss: 3056.28
# 10 Train total loss: 16826.4 	Reconstruction loss: 13945.5 	Latent loss: 2880.89
# 11 Train total loss: 16918.8 	Reconstruction loss: 13869.7 	Latent loss: 3049.1
# 12 Train total loss: 16541.6 	Reconstruction loss: 13349.6 	Latent loss: 3192.04
# 13 Train total loss: 16726.8 	Reconstruction loss: 13511.1 	Latent loss: 3215.65
# 14 Train total loss: 16827.8 	Reconstruction loss: 13470.4 	Latent loss: 3357.34
# 15 Train total loss: 15211.1 	Reconstruction loss: 12056.6 	Latent loss: 3154.45
# 16 Train total loss: 15884.4 	Reconstruction loss: 12621.7 	Latent loss: 3262.71
# 17 Train total loss: 15837.7 	Reconstruction loss: 12605.2 	Latent loss: 3232.5
# 18 Train total loss: 15667.8 	Reconstruction loss: 12536.9 	Latent loss: 3130.9
# 19 Train total loss: 16825.2 	Reconstruction loss: 13552.7 	Latent loss: 3272.53
# 20 Train total loss: 21479.1 	Reconstruction loss: 16821.4 	Latent loss: 4657.66
# 21 Train total loss: 16942.5 	Reconstruction loss: 13684.9 	Latent loss: 3257.57
# 22 Train total loss: 16348.6 	Reconstruction loss: 12785.5 	Latent loss: 3563.04
# 23 Train total loss: 16195.8 	Reconstruction loss: 12393.0 	Latent loss: 3802.82
# 24 Train total loss: 24344.9 	Reconstruction loss: 19611.0 	Latent loss: 4733.93
# 25 Train total loss: 15659.4 	Reconstruction loss: 12402.1 	Latent loss: 3257.26
# 26 Train total loss: 15391.3 	Reconstruction loss: 12027.1 	Latent loss: 3364.19
# 27 Train total loss: 16017.7 	Reconstruction loss: 12622.0 	Latent loss: 3395.66
# 28 Train total loss: 15850.7 	Reconstruction loss: 12296.8 	Latent loss: 3553.87
# 29 Train total loss: 15440.1 	Reconstruction loss: 12053.8 	Latent loss: 3386.28
# 30 Train total loss: 15321.4 	Reconstruction loss: 11859.5 	Latent loss: 3461.9
# 31 Train total loss: 28671.3 	Reconstruction loss: 24099.5 	Latent loss: 4571.79
# 32 Train total loss: 25359.7 	Reconstruction loss: 21115.4 	Latent loss: 4244.24
# 33 Train total loss: 26531.0 	Reconstruction loss: 21179.5 	Latent loss: 5351.53
# 34 Train total loss: 22320.2 	Reconstruction loss: 17480.8 	Latent loss: 4839.44
# 35 Train total loss: 16986.1 	Reconstruction loss: 13843.9 	Latent loss: 3142.15
# 36 Train total loss: 16471.7 	Reconstruction loss: 13194.8 	Latent loss: 3276.95
# 37 Train total loss: 15923.6 	Reconstruction loss: 12579.4 	Latent loss: 3344.26
# 38 Train total loss: 15041.1 	Reconstruction loss: 11747.6 	Latent loss: 3293.46
# 39 Train total loss: 15240.5 	Reconstruction loss: 12077.2 	Latent loss: 3163.36
# 40 Train total loss: 18162.1 	Reconstruction loss: 14394.3 	Latent loss: 3767.86
# 41 Train total loss: 15317.6 	Reconstruction loss: 11921.5 	Latent loss: 3396.08
# 42 Train total loss: 15946.5 	Reconstruction loss: 12579.5 	Latent loss: 3366.98
# 43 Train total loss: 17293.8 	Reconstruction loss: 13768.3 	Latent loss: 3525.56
# 44 Train total loss: 15724.1 	Reconstruction loss: 12234.7 	Latent loss: 3489.4
# 45 Train total loss: 15833.4 	Reconstruction loss: 12442.1 	Latent loss: 3391.31
# 46 Train total loss: 15360.5 	Reconstruction loss: 12037.0 	Latent loss: 3323.46
# 47 Train total loss: 19287.2 	Reconstruction loss: 16138.1 	Latent loss: 3149.12
# 48 Train total loss: 15315.5 	Reconstruction loss: 11791.8 	Latent loss: 3523.75
# 49 Train total loss: 15009.9 	Reconstruction loss: 11642.8 	Latent loss: 3367.16

# %%
import numpy as np

n_digits = 60
n_epochs = 50
batch_size = 150

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        n_batches = mnist.train.num_examples // batch_size
        for iteration in range(n_batches):
            print("\r{}%".format(100 * iteration // n_batches), end="") # not shown in the book
            sys.stdout.flush()                                          # not shown
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={X: X_batch})
        loss_val, reconstruction_loss_val, latent_loss_val = sess.run([loss, reconstruction_loss, latent_loss], feed_dict={X: X_batch}) # not shown
        print("\r{}".format(epoch), "Train total loss:", loss_val, "\tReconstruction loss:", reconstruction_loss_val, "\tLatent loss:", latent_loss_val)  # not shown
        saver.save(sess, "./my_model_variational.ckpt")  # not shown
    
    codings_rnd = np.random.normal(size=[n_digits, n_hidden3])
    outputs_val = outputs.eval(feed_dict={hidden3: codings_rnd})
# Out:
# 0 Train total loss: 29700.2 	Reconstruction loss: 24572.7 	Latent loss: 5127.58
# 1 Train total loss: 27205.0 	Reconstruction loss: 22376.9 	Latent loss: 4828.15
# 2 Train total loss: 34899.8 	Reconstruction loss: 26630.1 	Latent loss: 8269.72
# 3 Train total loss: 23109.7 	Reconstruction loss: 20507.5 	Latent loss: 2602.24
# 4 Train total loss: 21507.7 	Reconstruction loss: 18644.1 	Latent loss: 2863.59
# 59% Train total loss: 22048.9 	Reconstruction loss: 18731.1 	Latent loss: 3317.81
# 6 Train total loss: 18788.7 	Reconstruction loss: 15634.3 	Latent loss: 3154.47
# 7 Train total loss: 18748.1 	Reconstruction loss: 15678.9 	Latent loss: 3069.2
# 8 Train total loss: 17156.9 	Reconstruction loss: 14144.8 	Latent loss: 3012.0
# 9 Train total loss: 16486.3 	Reconstruction loss: 13352.3 	Latent loss: 3134.02
# 10 Train total loss: 16244.7 	Reconstruction loss: 13112.6 	Latent loss: 3132.05
# 11 Train total loss: 21993.9 	Reconstruction loss: 17367.8 	Latent loss: 4626.14
# 12 Train total loss: 16388.0 	Reconstruction loss: 13138.2 	Latent loss: 3249.82
# 13% Train total loss: 16664.0 	Reconstruction loss: 13419.4 	Latent loss: 3244.56
# 14 Train total loss: 25364.6 	Reconstruction loss: 18767.8 	Latent loss: 6596.77
# 15 Train total loss: 44243.8 	Reconstruction loss: 26082.2 	Latent loss: 18161.6
# 16 Train total loss: 30334.4 	Reconstruction loss: 23719.3 	Latent loss: 6615.14
# 17 Train total loss: 26989.7 	Reconstruction loss: 22607.2 	Latent loss: 4382.49
# 18 Train total loss: 22040.4 	Reconstruction loss: 18706.0 	Latent loss: 3334.37
# 19 Train total loss: 19311.6 	Reconstruction loss: 16101.9 	Latent loss: 3209.73
# 20 Train total loss: 16848.2 	Reconstruction loss: 13742.0 	Latent loss: 3106.2
# 21 Train total loss: 17051.8 	Reconstruction loss: 13802.3 	Latent loss: 3249.51
# 22 Train total loss: 16364.7 	Reconstruction loss: 13020.5 	Latent loss: 3344.25
# 23 Train total loss: 16483.1 	Reconstruction loss: 12988.4 	Latent loss: 3494.64
# 24 Train total loss: 16662.6 	Reconstruction loss: 13225.1 	Latent loss: 3437.47
# 25 Train total loss: 15874.0 	Reconstruction loss: 12370.0 	Latent loss: 3503.93
# 26 Train total loss: 15486.9 	Reconstruction loss: 12100.2 	Latent loss: 3386.71
# 27 Train total loss: 16004.8 	Reconstruction loss: 12667.0 	Latent loss: 3337.78
# 28 Train total loss: 15725.0 	Reconstruction loss: 12258.8 	Latent loss: 3466.19
# 29 Train total loss: 16188.0 	Reconstruction loss: 12879.9 	Latent loss: 3308.09
# 30 Train total loss: 16483.8 	Reconstruction loss: 12992.6 	Latent loss: 3491.27
# 31 Train total loss: 16045.3 	Reconstruction loss: 12568.2 	Latent loss: 3477.07
# 32 Train total loss: 35283.4 	Reconstruction loss: 23321.5 	Latent loss: 11961.9
# 33 Train total loss: 27964.9 	Reconstruction loss: 22879.6 	Latent loss: 5085.36
# 34 Train total loss: 25010.3 	Reconstruction loss: 20977.7 	Latent loss: 4032.54
# 35 Train total loss: 18973.6 	Reconstruction loss: 16034.9 	Latent loss: 2938.77
# 36 Train total loss: 16604.3 	Reconstruction loss: 13419.0 	Latent loss: 3185.24
# 37 Train total loss: 15652.7 	Reconstruction loss: 12401.2 	Latent loss: 3251.5
# 38 Train total loss: 15866.6 	Reconstruction loss: 12392.2 	Latent loss: 3474.36
# 39 Train total loss: 15792.2 	Reconstruction loss: 12278.3 	Latent loss: 3513.85
# 40 Train total loss: 15231.1 	Reconstruction loss: 11876.5 	Latent loss: 3354.59
# 41 Train total loss: 15920.3 	Reconstruction loss: 12428.1 	Latent loss: 3492.2
# 42 Train total loss: 15524.7 	Reconstruction loss: 12248.5 	Latent loss: 3276.19
# 43% Train total loss: 16725.9 	Reconstruction loss: 13219.5 	Latent loss: 3506.43
# 44 Train total loss: 15333.8 	Reconstruction loss: 11997.3 	Latent loss: 3336.51
# 45 Train total loss: 14970.5 	Reconstruction loss: 11501.0 	Latent loss: 3469.47
# 46 Train total loss: 15789.4 	Reconstruction loss: 12302.0 	Latent loss: 3487.4
# 47 Train total loss: 15954.7 	Reconstruction loss: 12541.4 	Latent loss: 3413.34
# 48 Train total loss: 15594.4 	Reconstruction loss: 12207.3 	Latent loss: 3387.14
# 49 Train total loss: 14944.9 	Reconstruction loss: 11552.6 	Latent loss: 3392.37

# %%
plt.figure(figsize=(8,50)) # not shown in the book
for iteration in range(n_digits):
    plt.subplot(n_digits, 10, iteration + 1)
    plot_image(outputs_val[iteration])
